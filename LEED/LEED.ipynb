# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_1=np.loadtxt("M9//I(E)-Experiment_2022-05-06_15-08-50.txt", comments="#", unpack=False, skiprows=1)

# %%
energy=data_1[:, 0]*2
#twiceenergy=[value*2 for value in energy] #[value * 3 for value in b_list]
Intensity=data_1[:, 2]
print(Intensity[1])
print(energy[3])
plt.plot(energy,Intensity,linestyle='dashed')
plt.xlim(0,800)
plt.ylim(4,90)
plt.show()
#print(data_1)
# Out:
# 7.350427
# 16.0

# %%
b_list = [2, 3, 4]
multiplied_list = [value * 3 for value in b_list]
print(multiplied_list[2])
# Out:
# 12

# %%
data_2=np.loadtxt("M9//I(E)-Experiment_2022-05-06_15-24-21.dat", comments="#", unpack=False, skiprows=1)

# %%
energy=data_2[:, 0]*2
Intensity=data_2[:, 2]
print(Intensity[1])
print(energy[3])
plt.plot(energy,Intensity,linestyle='dashed')
# Out:
# 2.075702
# 46.0
